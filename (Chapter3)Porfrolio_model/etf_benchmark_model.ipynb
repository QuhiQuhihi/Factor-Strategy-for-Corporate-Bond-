# %%
import os
import sys
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

from etf_benchmark_model import etf_benchmark

# %%
etf_benchmark = etf_benchmark()

etf_benchmark.run()
# Out:
# current dir is :  c:\workspace\Factor-Strategy-for-Corporate-Bond-\(Chapter3)Porfrolio_model
# main dir is :  C:\workspace\Factor-Strategy-for-Corporate-Bond-
# data dir is :  C:\workspace\Factor-Strategy-for-Corporate-Bond-\(Chapter1)Data
